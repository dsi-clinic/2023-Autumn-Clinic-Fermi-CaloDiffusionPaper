# %%
from eda_ae_funcs import Loss

# %%
loss_LR4e_5 = Loss("data/loss_LR4e-5.txt")
val_loss_LR4e_5 = Loss("data/val_loss_LR4e-5.txt")
loss_LR4e_4 = Loss("data/loss_LR4e-4.txt")
val_loss_LR4e_4 = Loss("data/val_loss_LR4e-4.txt")

# %%
loss_LR4e_5.visualize(scale='log', compare=[loss_LR4e_4])
val_loss_LR4e_5.visualize(scale='log', compare=[val_loss_LR4e_4])
